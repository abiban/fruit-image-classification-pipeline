# %% [markdown]
# # Reproducible Fruit Classification Pipeline
#
# This notebook executes the complete workflow:
#
# 1. Download dataset from Mendeley Data
# 2. Run image preprocessing
# 3. Run feature extraction and classification
# 4. Generate final outputs

# %%
print("=" * 80)
print("STEP 1: DOWNLOAD DATASET")
print("=" * 80)

# %run ../src/download_dataset.ipynb
# Out:
# ================================================================================
# STEP 1: DOWNLOAD DATASET
# ================================================================================
# Downloading dataset...
# Download complete.
# Extracting dataset...
# Copied: Banana
# Copied: Guava
#
# Dataset successfully installed.
# Location: C:\Users\abiba\Documents\fruit-image-classification-pipeline_Final\data\raw

# %%
import subprocess
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

PREPROCESS_NOTEBOOK = (
    PROJECT_ROOT
    / "notebooks"
    / "final_preprocessing_pipeline.ipynb"
)

print("=" * 80)
print("STEP 2: PREPROCESSING")
print("=" * 80)

subprocess.run(
    [
        "jupyter",
        "nbconvert",
        "--execute",
        "--to",
        "notebook",
        "--inplace",
        str(PREPROCESS_NOTEBOOK)
    ],
    check=True
)

print("Preprocessing completed.")
# Out:
# ================================================================================
# STEP 2: PREPROCESSING
# ================================================================================
# Preprocessing completed.

# %%
import subprocess
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

FEATURE_NOTEBOOK = (
    PROJECT_ROOT
    / "notebooks"
    / "reproducible_feature_extraction_pipeline.ipynb"
)

print("=" * 80)
print("STEP 3: FEATURE EXTRACTION AND CLASSIFICATION")
print("=" * 80)

subprocess.run(
    [
        "jupyter",
        "nbconvert",
        "--execute",
        "--to",
        "notebook",
        "--inplace",
        str(FEATURE_NOTEBOOK)
    ],
    check=True
)

print("=" * 80)
print("PIPELINE COMPLETED SUCCESSFULLY")
print("=" * 80)
print("Results saved in outputs/results/")
print("Models saved in outputs/models/")
print("Plots saved in outputs/plots/")
# Out:
# ================================================================================
# STEP 3: FEATURE EXTRACTION AND CLASSIFICATION
# ================================================================================
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[3], line 16
#      13 print("STEP 3: FEATURE EXTRACTION AND CLASSIFICATION")
#      14 print("=" * 80)
# ---> 16 subprocess.run(
#      17     [
#      18         "jupyter",
#      19         "nbconvert",
#      20         "--execute",
#      21         "--to",
#      22         "notebook",
#      23         "--inplace",
#      24         str(FEATURE_NOTEBOOK)
#      25     ],
#      26     check=True
#      27 )
#      29 print("=" * 80)
#      30 print("PIPELINE COMPLETED SUCCESSFULLY")
#
# File ~\anaconda3\Lib\subprocess.py:571, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     569     retcode = process.poll()
#     570     if check and retcode:
# --> 571         raise CalledProcessError(retcode, process.args,
#     572                                  output=stdout, stderr=stderr)
#     573 return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['jupyter', 'nbconvert', '--execute', '--to', 'notebook', '--inplace', 'C:\\Users\\abiba\\Documents\\fruit-image-classification-pipeline_Final\\notebooks\\reproducible_feature_extraction_pipeline.ipynb']' returned non-zero exit status 1.
